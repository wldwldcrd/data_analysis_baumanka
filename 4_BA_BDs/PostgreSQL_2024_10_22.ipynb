# %%
import pandas as pd

# %% [markdown]
# ### PSYCOPG

# %%
import psycopg2

# %%
con = psycopg2.connect(
    host = '192.168.1.21', ## localhost
    port =5432,
    user ='pi', # postgres
    password ='RAspberry',
    dbname = 'demo'
)

# %%
cursor = con.cursor()

# %%
sql = '''select * from actor limit 20'''

# %%
cursor.execute(sql)
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 cursor.execute(sql)
#
# InterfaceError: cursor already closed

# %%
data = cursor.fetchall()

# %%
for item in data:
    print(item[2])
# Out:
# Wahlberg
# Chase
# Davis
# Lollobrigida
# Nicholson

# %%
con.close()

# %% [markdown]
# ### SQLALCHEMY

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine("postgresql+psycopg2://pi:RAspberry@192.168.1.21/demo", echo=True)

# %%
df = pd.read_sql_query(sql=sql,con=engine)
# Out:
# 2024-10-22 21:23:16,966 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2024-10-22 21:23:16,967 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-10-22 21:23:16,978 INFO sqlalchemy.engine.Engine select current_schema()
# 2024-10-22 21:23:16,979 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-10-22 21:23:17,007 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2024-10-22 21:23:17,009 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-10-22 21:23:17,016 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-22 21:23:17,017 INFO sqlalchemy.engine.Engine select * from actor limit 20
# 2024-10-22 21:23:17,018 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-10-22 21:23:17,033 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
df.head()
# Out:
#    actor_id first_name     last_name             last_update
# 0         2       Nick      Wahlberg 2013-05-26 14:47:57.620
# 1         3         Ed         Chase 2013-05-26 14:47:57.620
# 2         4   Jennifer         Davis 2013-05-26 14:47:57.620
# 3         5     Johnny  Lollobrigida 2013-05-26 14:47:57.620
# 4         6      Bette     Nicholson 2013-05-26 14:47:57.620

# %%
df = pd.read_sql_table(table_name='film', con=engine)
# Out:
# 2024-10-22 21:25:00,744 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-22 21:25:00,746 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# WHERE pg_catalog.pg_class.relname = %(table_name)s AND pg_catalog.pg_class.relkind = ANY (ARRAY[%(param_1)s, %(param_2)s, %(param_3)s, %(param_4)s, %(param_5)s]) AND pg_catalog.pg_table_is_visible(pg_catalog.pg_class.oid) AND pg_catalog.pg_namespace.nspname != %(nspname_1)s
# 2024-10-22 21:25:00,748 INFO sqlalchemy.engine.Engine [cached since 31.71s ago] {'table_name': 'film', 'param_1': 'r', 'param_2': 'p', 'param_3': 'f', 'param_4': 'v', 'param_5': 'm', 'nspname_1': 'pg_catalog'}
# 2024-10-22 21:25:00,756 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# ...

# %%
df.head()
# Out:
#    film_id              title  \
# 0      133    Chamber Italian
# 1      384   Grosse Wonderful
# 2        8    Airport Pollock
# 3       98  Bright Encounters
# 4        1   Academy Dinosaur
#
#                                          description  release_year  \
# 0  A Fateful Reflection of a Moose And a Husband ...          2006
# 1  A Epic Drama of a Cat And a Explorer who must ...          2006
# 2  A Epic Tale of a Moose And a Girl who must Con...          2006
# 3  A Fateful Yarn of a Lumberjack And a Feminist ...          2006
# 4  A Epic Drama of a Feminist And a Mad Scientist...          2006
#
#    language_id  rental_duration  rental_rate  length  replacement_cost rating  \
# 0            1                7         4.99     117             14.99  NC-17
# 1            1                5         4.99      49             19.99      R
# 2            1                6         4.99      54             15.99      R
# ...
