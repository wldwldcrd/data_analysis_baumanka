# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Matplotlib
# https://matplotlib.org/

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Simple graph

# %%
x = np.linspace(1,25,50)
y = np.sin(x) + np.random.rand()
fig = plt.figure()
plt.plot(x,y)

# %% [markdown]
# ### Size of canvas

# %%
fig = plt.figure(figsize=(12,3))
plt.plot(x,y, 'v--', lw=0.75, color='red')

# %% [markdown]
# ### X/Y labels

# %%
fig = plt.figure(figsize=(12,3))
plt.plot(x,y, 'v--', lw=0.75, color='red')
plt.xlabel('X-dim', fontsize=12)
plt.ylabel('Y-dim',fontsize=12)
# Out:
# Text(0, 0.5, 'Y-dim')

# %% [markdown]
# ### Grid.

# %%
fig = plt.figure(figsize=(12,3))
plt.grid(visible=True)
plt.plot(x,y, 'x--', lw=0.75, color='red')
plt.xlabel('X-dim', fontsize=12)
plt.ylabel('Y-dim',fontsize=12)
# Out:
# Text(0, 0.5, 'Y-dim')

# %% [markdown]
# ### Legend

# %%
fig = plt.figure(figsize=(12,3))
plt.grid(visible=True)
plt.plot(x,y, 'x--', lw=0.75, color='red', label='X-dim vs. Y-dim')
plt.xlabel('X-dim', fontsize=12)
plt.ylabel('Y-dim',fontsize=12)
plt.legend(loc='upper left')

# %%
z = np.cos(x) + 2 * np.cos(x)
fig = plt.figure(figsize=(12,3))
plt.grid(visible=True)
plt.plot(x,y, 'x--', lw=0.75, color='red', label='X-dim vs. Y-dim')
plt.plot(x,z,color='violet', label = 'X-dim vs. Z-dim')
plt.xlabel('X-dim', fontsize=12)
plt.ylabel('Y-dim',fontsize=12)
plt.legend(loc='upper left')#, ncols=2)

# %% [markdown]
# ### Xlim/Ylim

# %%
fig = plt.figure(figsize=(12,4))
plt.grid(visible=True)
plt.plot(x,y, 'x--', lw=0.75, color='red', label='X-dim vs. Y-dim')
plt.plot(x,z,color='violet', label = 'X-dim vs. Z-dim')
plt.xlim(5, 15)
plt.ylim(-2,2)
plt.xlabel('X-dim', fontsize=12)
plt.ylabel('Y-dim',fontsize=12)
plt.legend(loc='lower left', ncols=2)

# %% [markdown]
# ### Style
#
# plt.style.available

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('_mpl-gallery')

# %%
fig = plt.figure(figsize=(12,4))
plt.grid(visible=True)
plt.plot(x,y, 'x--', lw=0.75, color='red', label='X-dim vs. Y-dim')
plt.plot(x,z,color='violet', label = 'X-dim vs. Z-dim')
plt.ylim(-4.5, 4.5)
plt.xlabel('X-dim', fontsize=12)
plt.ylabel('Y-dim',fontsize=12)
plt.legend(loc='lower left', ncols=2)
plt.show()
plt.savefig('2.pdf')

# %% [markdown]
# ### Subplots

# %%
fig, axes = plt.subplots(2,2, figsize=(12,4))
axes[0][0].plot(x,y, 'x--', lw=0.75, color='red', label='X-dim vs. Y-dim')
axes[0][0].legend()
axes[1][1].plot(x,z,color='violet', label = 'X-dim vs. Z-dim')
plt.tight_layout()
plt.show()

# %%
fig.savefig('1.png')

# %%
#fig = plt.figure(figsize=(12,4))
plt.grid(visible=True)
plt.plot(x,y, 'x--', lw=0.75, color='red', label='X-dim vs. Y-dim')
plt.plot(x,z,color='violet', label = 'X-dim vs. Z-dim')
plt.ylim(-4.5, 4.5)
plt.xlabel('X-dim', fontsize=12)
plt.ylabel('Y-dim',fontsize=12)
plt.legend(loc='lower left', ncols=2)
plt.show()

# %%
plt.savefig('1.jpg')

# %% [markdown]
# ### Different types of graphs

# %% [markdown]
# #### Bar plot

# %%
x = 0.5 + np.arange(8)
y = [4.8, 5.5, 3.5, 4.6, 6.5, 6.6, 2.6, 3.0]

fig, ax = plt.subplots()

ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)

ax.set(xlim=(0, 12), xticks=np.arange(1, 8),
       ylim=(0, 12), yticks=np.arange(1, 8))

plt.show()

# %% [markdown]
# #### Stack plot

# %%
x = np.arange(0, 10, 2)
ay = [1, 1.25, 2, 2.75, 3]
by = [1, 1, 1, 1, 1]
cy = [2, 1, 2, 1, 2]
y = np.vstack([ay, by, cy])


fig, ax = plt.subplots()

ax.stackplot(x, y)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %% [markdown]
# #### Histogramm

# %%
np.random.seed(1)
x = 4 + np.random.normal(0, 1.5, 200)


fig, ax = plt.subplots()

ax.hist(x, bins=8, linewidth=0.5, edgecolor="white")

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 56), yticks=np.linspace(0, 56, 9))

plt.show()

# %% [markdown]
# #### Pie plot

# %%
x = [1, 2, 3, 4]
colors = plt.get_cmap('Blues')(np.linspace(0.2, 0.7, len(x)))


fig, ax = plt.subplots()
ax.pie(x, colors=colors, radius=3, center=(4, 4),
       wedgeprops={"linewidth": 1, "edgecolor": "white"}, frame=True)

ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %% [markdown]
# #### 3D scatter plot

# %%
np.random.seed(19680801)
n = 100
rng = np.random.default_rng()
xs = rng.uniform(23, 32, n)
ys = rng.uniform(0, 100, n)
zs = rng.uniform(-50, -25, n)

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})
ax.scatter(xs, ys, zs)

ax.set(xticklabels=[],
       yticklabels=[],
       zticklabels=[])

plt.show()

# %% [markdown]
# ## Seaborn
# https://seaborn.pydata.org/

# %%
import seaborn as sns

# %% [markdown]
# ### Seaborn dataset

# %%
df = sns.load_dataset('penguins')

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# ### Simple scatterplot

# %%
sns.set_style('white')

# %%
sns.scatterplot(data=df, x='bill_length_mm', y='flipper_length_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %% [markdown]
# ### Relplot. Kind - scatter

# %%
sns.relplot(data=df, x='bill_length_mm', y='flipper_length_mm', kind='scatter')

# %% [markdown]
# #### Adding column (col)

# %%
sns.relplot(data=df, x='bill_length_mm', y='flipper_length_mm', kind='scatter',col='sex')
plt.show()

# %% [markdown]
# #### Adding hue by categorical column (species)

# %%
sns.relplot(data=df, x='bill_length_mm', y='flipper_length_mm', kind='scatter', hue='species')

# %% [markdown]
# #### Adding hue by number column (body_mass_g)

# %%
sns.relplot(data=df, x='bill_length_mm', y='flipper_length_mm', kind='scatter', hue='body_mass_g')

# %% [markdown]
# #### Using size instead of hue

# %%
sns.relplot(data=df, x='bill_length_mm', y='flipper_length_mm', kind='scatter', size='body_mass_g')

# %% [markdown]
# ### Confidence interval

# %% [markdown]
# #### Dataset flights

# %%
df = sns.load_dataset('flights')

# %%
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %% [markdown]
# #### Automatic confidence interval

# %%
sns.relplot(data=df, x='year', y='passengers', kind='line')

# %% [markdown]
# ### Distplots

# %% [markdown]
# #### Penguins are back

# %%
df = sns.load_dataset('penguins')

# %%
df.head()

# %% [markdown]
# #### Simple displot by body mass

# %%
sns.displot(data=df, x='body_mass_g', kind='hist', bins=7)

# %% [markdown]
# #### Adding hue to the displot

# %%
sns.displot(data=df, x='body_mass_g', kind='hist', bins=20, hue='species')

# %%
sns.displot(data=df, x='body_mass_g', kind='kde', hue='species')

# %% [markdown]
# #### Changing type. KDE (no bins)

# %% [markdown]
# #### Displot with 2 columns by X and Y with cbar

# %% [markdown]
# ### Jointplot

# %%
sns.jointplot(data=df, x='bill_length_mm', y ='flipper_length_mm', hue='species', legend=False)

# %% [markdown]
# ### Heatmap

# %%
df[df.describe().columns].corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %%
sns.heatmap(df[df.describe().columns].corr(),annot=True, fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# ### Categorical plot

# %%
sns.catplot(data=df, x='species', y ='flipper_length_mm', kind='bar')

# %% [markdown]
# ### Regression

# %%
model = sns.lmplot(data=df, x='bill_length_mm', y = 'flipper_length_mm', hue='island')
