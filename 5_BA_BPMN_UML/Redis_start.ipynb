# %%
import redis

# %%
client = redis.Redis(host='192.168.1.21',port='6379')

# %%
client.set('name','John', ex = 5)

# %%
client.get('name').decode()

# %%
client.hset('user','name','Andrey')

# %%
client.hset('user','age',50)

# %%
client.hget('user','age')

# %%
client.lpush('stack',2)

# %%
client.set('name','Cinderella')

# %%
name = client.get('name')
name.decode()
