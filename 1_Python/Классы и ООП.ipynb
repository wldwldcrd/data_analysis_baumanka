# %%
class Animal:
  age = 6
  weight = 4.5

# %%
a1 = Animal()

# %%
a1.weight
# Out:
# 4.5

# %%
a2 = Animal()

# %%
a2.weight
# Out:
# 4.5

# %%
a1.age = 10

# %%
a1.age
# Out:
# 10

# %%
a2.age
# Out:
# 6

# %%
class Animal:
  def __init__(self, age, weight):
    self.age = age
    self.weight = weight

# %%
a1 = Animal(6, 4.5)

# %%
a2 = Animal(10,7)

# %%
a1.age = 12

# %%
a2.age
# Out:
# 10

# %%
a1.age
# Out:
# 12

# %%
class Animal():
  def __init__(self, age, weight, name):
    self.__age = age
    self.__weight = weight
    self.__name = name

  def set_name(self, name):
    self.__name = name

  def set_older(self):
    self.__age += 1

  def sound(self):
    print('RRRR!!!')

# %%
a1 = Animal(5,3.5, 'Verberal')

# %%
a1.__name = 'fff'

# %%
a1._Animal__name
# Out:
# 'Verberal'

# %%
a1.__dict__
# Out:
# {'_Animal__age': 5,
#  '_Animal__weight': 3.5,
#  '_Animal__name': 'Verberal',
#  '__name': 'fff'}

# %%
a1.set_name('aaa')

# %%
a1._name
# Out:
# 'aaa'

# %%
class Animal():
  def __init__(self, age, weight, name):
    self.age = age
    self.weight = weight
    self.name = name

  def set_name(self, name):
    self.name = name

  def set_older(self):
    self.age += 1

  def sound(self):
    print('RRRR!!!')

# %%
class Cat(Animal):
    def __init__(self, age, weight, name, pawns):
      super().__init__(age,weight,name)
      self.pawns = pawns

    def sound(self):
      print('Meow!!!')

# %%
c1 = Cat(4,2,'Catty',4)

# %%
c1.__dict__
# Out:
# {'age': 4, 'weight': 2, 'name': 'Catty', 'pawns': 4}

# %%
c1.set_older()

# %%
c1.__dict__
# Out:
# {'age': 5, 'weight': 2, 'name': 'Catty', 'pawns': 4}

# %%
c1.sound()
# Out:
# Meow!!!
