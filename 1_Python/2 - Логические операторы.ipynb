# %% [markdown]
# ## Логические операторы (>, <, ==, !=, >=, <=, |, &, ^)
#
# ### <font color="red"> ВНИМАНИЕ: Оператор проверки на равенство: == </font>

# %%
4 > 5

# %%
7 == 8

# %%
6 > 5

# %%
6 >= 6

# %%
4 <= 5

# %%
3 != 3

# %%
(3 > 2) ^ (4 != 4)

# %%
not (4 > 3)

# %% [markdown]
# & - and
#
# | - or
#
# not

# %% [markdown]
# ### Приоритет операций
# ### AND - 1
# ### OR - 2
# ### NOT - 3
