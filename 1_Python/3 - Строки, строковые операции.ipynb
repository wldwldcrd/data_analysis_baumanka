# %% [markdown]
# ## Строки в Python

# %%
var = 1_000_000
var

# %% [markdown]
# ### Определение. Кавычки (1, 2, 3)

# %%
str_1 = 'Hello'
str_2 = "Hello_"

# %%
str_2

# %%
str_3 = """
Мама
мыла
раму
"""
print(str_3)

# %% [markdown]
# ### Базовые операции
# #### Сложение, умножение
#
# #### Конвертация

# %%
str_1 = "Hello "
str_2 = "World"

str_1 + str_2

# %%
str_1 * 5

# %%
str_1 - str_2

# %% [markdown]
# #### Код символов. Сравнение символов и строк

# %%
ord('A')

# %%
chr(67)

# %%
'Кот' > 'кит'

# %% [markdown]
# #### Вхождение подстроки в строку. Длина строки

# %%
len('Weather')

# %%
str_1 = 'weather'
'at' in str_1

# %% [markdown]
# ### Срезы строк, Индексы

# %%
str_1[1:2]

# %% [markdown]
# ### <font color='red'>Внимание:<br>1. Последний индекс в срезе не включается в выборку<br>2. Срез начинается с 0</font>

# %%
str_1 = 'We seems inside a goldmine'

# %%
str_1[0:10:2]

# %%
str_1[:8]

# %%
str_1[::-1]

# %% [markdown]
# ### Основные методы строк

# %%
a = 1

# %%
type(a)

# %% [markdown]
# #### Upper. Lower

# %%
str_2 = str_1.upper()
str_2

# %%
str_1.lower()

# %%
str_2

# %% [markdown]
# #### Find. Index. Count

# %%
str_1

# %%
str_1.find('id')

# %%
'id' in str_1

# %%
str_1.index('e')

# %%
str_2.count('E')

# %% [markdown]
# #### Isalpha. Isdigit. Isalnum

# %%
str_3 = '45'

# %%
str_3.isdigit()

# %% [markdown]
# #### Strip.Split

# %%
str_4 = '   the_world_is_stage   '

# %%
str_4.strip().split(sep='_')

# %%
str_4.strip?

# %%
str_4.split()

# %%
str_4.split(sep='_')

# %%
str_1 = 'okokokok dodod - kokok'
str_1.split(sep='-')[1].strip()

# %% [markdown]
# ### Спецсимволы. Подстановка

# %%
str_6 = 'Мама\tмыла\tраму'
print(str_6)

# %% [markdown]
# ### Форматированный вывод строк

# %%
str_1 = "La vida "
str_2 = 'es sueno '
str_3 = 'Calderon de la Barca'


str_1 + str_2 + str_3

# %%
'Book {} {} written by {}'.format(str_1, str_2, str_3)

# %%
f'Book {str_1} {str_2} written by {str_3}'

# %% [markdown]
# ### Join

# %%
str_4 = "Ма"
str_5 = "ма"

''.join(str_4) + str_5

# %%
'' + str_4 + str_5
