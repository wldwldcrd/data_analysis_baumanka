# %% [markdown]
# ## Pandas - panel data
# https://pandas.pydata.org/docs/

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Creating DataFrames

# %% [markdown]
# ### 2. Basic info about the data

# %% [markdown]
# ### 3. Data types. Converting one to another

# %% [markdown]
# ### 4. Slicing. loc. Iloc

# %% [markdown]
# ### 5. Indexes. Set. Reset

# %% [markdown]
# ### 6. Conditional filtering. Query

# %% [markdown]
# ### 7. Adding, renaming, deleting columns

# %% [markdown]
# ### 8. Row wise functions. Apply, transform

# %% [markdown]
# ### Применение

# %% [markdown]
# #### Рассчитать сгруппированный по годам доход в 11 месяце

# %% [markdown]
# #### Общее кол-во проданного товара для региона West в категории Beverages по годам

# %% [markdown]
# ### Сводные таблицы
