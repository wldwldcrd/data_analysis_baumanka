# %% [markdown]
# <b>https://numpy.org/doc/stable/user/index.html</b>

# %%
import numpy as np

# %%
np.__version__

# %% [markdown]
# ### Filling Arrays
#
#
# 1.   np.full / np.full_like
# 2.   np.zeros
# 3.   np.ones
# 4.   np.identity
# 5.   np.random.rand / randint / randn
# 6.   np.arange / np.linspace

# %% [markdown]
# ### Data Types. Indexing.
# 1. Ndim / Shape / Size
# 2. Dtype / Itemsize / Nbytes
# 3. Indexing / Slicing
# 4. np.random.sample / np.repeat

# %% [markdown]
# ### NaN and Inf

# %% [markdown]
# ### Mathematical operations. Difference between Python and Numpy lists
# 1.  Basic Python math vs. Numpy math
# 2.  Aggregate functions (sum, avg, etc.)

# %% [markdown]
# ### Array methods
# 1.  Insert/Append/Delete
# 2.  Sqrt/Sin/Cos, etc
# 3.  Reshape
# 4.  Argmax / Argmin
# 5.  Where
# 6.  Hstack / Vstack
# 7.  Flatten / Ravel / T

# %% [markdown]
# ### Concatenation

# %% [markdown]
# ### Концепция "маскирования" в NumPy:

# %% [markdown]
# ### Exporting / Importing Numpy arrays
# 1. Savetxt
# 2. Loadtxt
